# %% [markdown]
# <h1 align=center><font size = 5>Regression Models with Keras</font></h1>
#
# <h1 align=center><font size = 5>Muhammad Zeeshan</font></h1>
#
# <h1 align=center><font size = 5>Machine learning Engineer</font></h1>

# %% [markdown]
# ## Introduction

# %% [markdown]
# As we discussed in the videos, despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow in the other courses.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# <h2>Regression Models with Keras</h2>
#
# <h3>Objective for this Notebook<h3>
# <h5> 1. How to use the Keras library to build a regression model.</h5>
# <h5> 2. Download and Clean dataset </h5>
# <h5> 3. Build a Neural Network </h5>
# <h5> 4. Train and Test the Network. </h5>

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean Dataset</a>
# 2. <a href="#item32">Import Keras</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean Dataset

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# If you run this notebook on a different environment, e.g. your desktop, you may need to uncomment and install certain libraries.

# !pip install numpy==1.21.4
# !pip install pandas==1.3.4
# !pip install keras==2.1.6
# Out:
# Collecting numpy==1.21.4
#   Downloading numpy-1.21.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 31.7 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# flax 0.7.5 requires numpy>=1.22, but you have numpy 1.21.4 which is incompatible.
# jax 0.4.20 requires numpy>=1.22, but you have numpy 1.21.4 which is incompatible.
# jaxlib 0.4.20+cuda11.cudnn86 requires numpy>=1.22, but you have numpy 1.21.4 which is incompatible.
# numba 0.58.1 requires numpy<1.27,>=1.22, but you have numpy 1.21.4 which is incompatible.
# plotnine 0.12.4 requires numpy>=1.23.0, but you have numpy 1.21.4 which is incompatible.
# scipy 1.11.3 requires numpy<1.28.0,>=1.21.6, but you have numpy 1.21.4 which is incompatible.
# tensorflow 2.14.0 requires numpy>=1.23.5, but you have numpy 1.21.4 which is incompatible.
# Successfully installed numpy-1.21.4
# Collecting pandas==1.3.4
#   Downloading pandas-1.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 73.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.4) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.4) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.4) (1.21.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.4) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# bigframes 0.13.0 requires pandas>=1.5.0, but you have pandas 1.3.4 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 1.3.4 which is incompatible.
# mizani 0.9.3 requires pandas>=1.3.5, but you have pandas 1.3.4 which is incompatible.
# plotnine 0.12.4 requires numpy>=1.23.0, but you have numpy 1.21.4 which is incompatible.
# plotnine 0.12.4 requires pandas>=1.5.0, but you have pandas 1.3.4 which is incompatible.
# xarray 2023.7.0 requires pandas>=1.4, but you have pandas 1.3.4 which is incompatible.
# Successfully installed pandas-1.3.4
# Collecting keras==2.1.6
#   Downloading Keras-2.1.6-py2.py3-none-any.whl (339 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 339.6/339.6 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras==2.1.6) (1.21.4)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.10/dist-packages (from keras==2.1.6) (1.11.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras==2.1.6) (1.16.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from keras==2.1.6) (6.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras==2.1.6) (3.9.0)
# Collecting numpy>=1.9.1 (from keras==2.1.6)
#   Downloading numpy-1.26.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 69.6 MB/s eta 0:00:00
# Installing collected packages: numpy, keras
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.4
#     Uninstalling numpy-1.21.4:
#       Successfully uninstalled numpy-1.21.4
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# cupy-cuda11x 11.0.0 requires numpy<1.26,>=1.20, but you have numpy 1.26.1 which is incompatible.
# mizani 0.9.3 requires pandas>=1.3.5, but you have pandas 1.3.4 which is incompatible.
# plotnine 0.12.4 requires pandas>=1.5.0, but you have pandas 1.3.4 which is incompatible.
# tensorflow 2.14.0 requires keras<2.15,>=2.14.0, but you have keras 2.1.6 which is incompatible.
# xarray 2023.7.0 requires pandas>=1.4, but you have pandas 1.3.4 which is incompatible.
# Successfully installed keras-2.1.6 numpy-1.26.1

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have.

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ## Import Keras

# %% [markdown]
# Recall from the videos that Keras normally runs on top of a low-level library such as TensorFlow. This means that to be able to use the Keras library, you will have to install TensorFlow first and when you import the Keras library, it will be explicitly displayed what backend was used to install the Keras library. In CC Labs, we used TensorFlow as the backend to install Keras, so it should clearly print that when we import Keras.

# %% [markdown]
# #### Let's go ahead and import the Keras library

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Collecting keras<2.15,>=2.14.0 (from tensorflow)
#   Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.41.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.1.6
#     Uninstalling Keras-2.1.6:
#       Successfully uninstalled Keras-2.1.6
# Successfully installed keras-2.14.0

# %% [markdown]
# As you can see, the TensorFlow backend was used to install the Keras library.

# %% [markdown]
# Let's import the rest of the packages from the Keras library that we will need to build our regressoin model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# <a id='item34'></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 0s - loss: 25.9961 - val_loss: 133.3478 - 180ms/epoch - 8ms/step
# Epoch 2/100
# 23/23 - 0s - loss: 25.2819 - val_loss: 119.3904 - 123ms/epoch - 5ms/step
# Epoch 3/100
# 23/23 - 0s - loss: 25.4313 - val_loss: 127.9508 - 143ms/epoch - 6ms/step
# Epoch 4/100
# 23/23 - 0s - loss: 25.0681 - val_loss: 120.9675 - 126ms/epoch - 5ms/step
# Epoch 5/100
# 23/23 - 0s - loss: 25.1045 - val_loss: 123.6458 - 126ms/epoch - 5ms/step
# Epoch 6/100
# 23/23 - 0s - loss: 25.1326 - val_loss: 123.2554 - 129ms/epoch - 6ms/step
# Epoch 7/100
# 23/23 - 0s - loss: 25.0011 - val_loss: 131.5665 - 209ms/epoch - 9ms/step
# Epoch 8/100
# 23/23 - 0s - loss: 25.9271 - val_loss: 134.9418 - 123ms/epoch - 5ms/step
# Epoch 9/100
# 23/23 - 0s - loss: 25.2610 - val_loss: 131.9293 - 123ms/epoch - 5ms/step
# Epoch 10/100
# 23/23 - 0s - loss: 25.4655 - val_loss: 130.5723 - 139ms/epoch - 6ms/step
# Epoch 11/100
# 23/23 - 0s - loss: 24.6124 - val_loss: 120.1513 - 114ms/epoch - 5ms/step
# Epoch 12/100
# 23/23 - 0s - loss: 24.7263 - val_loss: 118.9479 - 120ms/epoch - 5ms/step
# Epoch 13/100
# 23/23 - 0s - loss: 23.8031 - val_loss: 119.2290 - 156ms/epoch - 7ms/step
# Epoch 14/100
# 23/23 - 0s - loss: 23.9486 - val_loss: 117.6647 - 121ms/epoch - 5ms/step
# Epoch 15/100
# 23/23 - 0s - loss: 23.7840 - val_loss: 134.2962 - 125ms/epoch - 5ms/step
# Epoch 16/100
# 23/23 - 0s - loss: 24.2883 - val_loss: 129.0578 - 116ms/epoch - 5ms/step
# Epoch 17/100
# 23/23 - 0s - loss: 23.7337 - val_loss: 124.3201 - 153ms/epoch - 7ms/step
# Epoch 18/100
# 23/23 - 0s - loss: 23.5784 - val_loss: 104.5670 - 121ms/epoch - 5ms/step
# Epoch 19/100
# 23/23 - 0s - loss: 23.3405 - val_loss: 118.6664 - 169ms/epoch - 7ms/step
# Epoch 20/100
# 23/23 - 0s - loss: 22.9314 - val_loss: 124.7370 - 130ms/epoch - 6ms/step
# Epoch 21/100
# 23/23 - 0s - loss: 22.7387 - val_loss: 116.4537 - 170ms/epoch - 7ms/step
# Epoch 22/100
# 23/23 - 0s - loss: 22.6594 - val_loss: 122.2674 - 146ms/epoch - 6ms/step
# Epoch 23/100
# 23/23 - 0s - loss: 22.7924 - val_loss: 105.4319 - 155ms/epoch - 7ms/step
# Epoch 24/100
# 23/23 - 0s - loss: 22.7921 - val_loss: 115.2431 - 147ms/epoch - 6ms/step
# Epoch 25/100
# 23/23 - 0s - loss: 22.5497 - val_loss: 121.9154 - 176ms/epoch - 8ms/step
# Epoch 26/100
# 23/23 - 0s - loss: 22.7659 - val_loss: 114.8583 - 166ms/epoch - 7ms/step
# Epoch 27/100
# 23/23 - 0s - loss: 22.2482 - val_loss: 110.8298 - 122ms/epoch - 5ms/step
# Epoch 28/100
# 23/23 - 0s - loss: 22.1256 - val_loss: 113.1717 - 164ms/epoch - 7ms/step
# Epoch 29/100
# 23/23 - 0s - loss: 21.9784 - val_loss: 111.4604 - 173ms/epoch - 8ms/step
# Epoch 30/100
# 23/23 - 0s - loss: 22.0265 - val_loss: 108.1775 - 119ms/epoch - 5ms/step
# Epoch 31/100
# 23/23 - 0s - loss: 21.4659 - val_loss: 122.8310 - 180ms/epoch - 8ms/step
# Epoch 32/100
# 23/23 - 0s - loss: 21.5598 - val_loss: 118.2390 - 161ms/epoch - 7ms/step
# Epoch 33/100
# 23/23 - 0s - loss: 21.5945 - val_loss: 110.4198 - 147ms/epoch - 6ms/step
# Epoch 34/100
# 23/23 - 0s - loss: 21.3824 - val_loss: 114.6125 - 168ms/epoch - 7ms/step
# Epoch 35/100
# 23/23 - 0s - loss: 21.6805 - val_loss: 116.7631 - 182ms/epoch - 8ms/step
# Epoch 36/100
# 23/23 - 0s - loss: 21.7425 - val_loss: 114.3053 - 160ms/epoch - 7ms/step
# Epoch 37/100
# 23/23 - 0s - loss: 21.4373 - val_loss: 119.9753 - 117ms/epoch - 5ms/step
# Epoch 38/100
# 23/23 - 0s - loss: 20.8244 - val_loss: 115.4911 - 82ms/epoch - 4ms/step
# Epoch 39/100
# 23/23 - 0s - loss: 21.1192 - val_loss: 112.7843 - 77ms/epoch - 3ms/step
# Epoch 40/100
# 23/23 - 0s - loss: 21.4571 - val_loss: 105.9827 - 88ms/epoch - 4ms/step
# Epoch 41/100
# 23/23 - 0s - loss: 20.4597 - val_loss: 124.5577 - 81ms/epoch - 4ms/step
# Epoch 42/100
# 23/23 - 0s - loss: 20.6567 - val_loss: 113.0628 - 99ms/epoch - 4ms/step
# Epoch 43/100
# 23/23 - 0s - loss: 20.3624 - val_loss: 108.9729 - 89ms/epoch - 4ms/step
# Epoch 44/100
# 23/23 - 0s - loss: 20.5656 - val_loss: 107.0897 - 86ms/epoch - 4ms/step
# Epoch 45/100
# 23/23 - 0s - loss: 20.7471 - val_loss: 108.1831 - 102ms/epoch - 4ms/step
# Epoch 46/100
# 23/23 - 0s - loss: 20.1280 - val_loss: 112.8992 - 95ms/epoch - 4ms/step
# Epoch 47/100
# 23/23 - 0s - loss: 20.0083 - val_loss: 125.8030 - 94ms/epoch - 4ms/step
# Epoch 48/100
# 23/23 - 0s - loss: 19.8425 - val_loss: 112.5985 - 90ms/epoch - 4ms/step
# Epoch 49/100
# 23/23 - 0s - loss: 20.1849 - val_loss: 110.7152 - 84ms/epoch - 4ms/step
# Epoch 50/100
# 23/23 - 0s - loss: 19.8397 - val_loss: 111.2159 - 90ms/epoch - 4ms/step
# Epoch 51/100
# 23/23 - 0s - loss: 20.1943 - val_loss: 112.0628 - 88ms/epoch - 4ms/step
# Epoch 52/100
# 23/23 - 0s - loss: 19.6807 - val_loss: 112.0064 - 102ms/epoch - 4ms/step
# Epoch 53/100
# 23/23 - 0s - loss: 19.7435 - val_loss: 105.5488 - 89ms/epoch - 4ms/step
# Epoch 54/100
# 23/23 - 0s - loss: 19.4260 - val_loss: 117.3943 - 84ms/epoch - 4ms/step
# Epoch 55/100
# 23/23 - 0s - loss: 19.2556 - val_loss: 115.1913 - 100ms/epoch - 4ms/step
# Epoch 56/100
# 23/23 - 0s - loss: 19.5110 - val_loss: 119.7211 - 94ms/epoch - 4ms/step
# Epoch 57/100
# 23/23 - 0s - loss: 19.1864 - val_loss: 108.1681 - 87ms/epoch - 4ms/step
# Epoch 58/100
# 23/23 - 0s - loss: 19.1781 - val_loss: 108.4687 - 92ms/epoch - 4ms/step
# Epoch 59/100
# 23/23 - 0s - loss: 19.0709 - val_loss: 110.4712 - 79ms/epoch - 3ms/step
# Epoch 60/100
# 23/23 - 0s - loss: 19.0420 - val_loss: 117.1144 - 81ms/epoch - 4ms/step
# Epoch 61/100
# 23/23 - 0s - loss: 19.0242 - val_loss: 105.0177 - 84ms/epoch - 4ms/step
# Epoch 62/100
# 23/23 - 0s - loss: 19.1213 - val_loss: 101.1588 - 90ms/epoch - 4ms/step
# Epoch 63/100
# 23/23 - 0s - loss: 18.5415 - val_loss: 118.2890 - 86ms/epoch - 4ms/step
# Epoch 64/100
# 23/23 - 0s - loss: 18.7118 - val_loss: 114.4483 - 79ms/epoch - 3ms/step
# Epoch 65/100
# 23/23 - 0s - loss: 18.8477 - val_loss: 113.0221 - 83ms/epoch - 4ms/step
# Epoch 66/100
# 23/23 - 0s - loss: 18.3529 - val_loss: 107.0638 - 90ms/epoch - 4ms/step
# Epoch 67/100
# 23/23 - 0s - loss: 18.4436 - val_loss: 111.5842 - 96ms/epoch - 4ms/step
# Epoch 68/100
# 23/23 - 0s - loss: 18.2641 - val_loss: 107.7509 - 96ms/epoch - 4ms/step
# Epoch 69/100
# 23/23 - 0s - loss: 18.0337 - val_loss: 108.0636 - 93ms/epoch - 4ms/step
# Epoch 70/100
# 23/23 - 0s - loss: 17.8576 - val_loss: 111.4993 - 85ms/epoch - 4ms/step
# Epoch 71/100
# 23/23 - 0s - loss: 17.9192 - val_loss: 107.9029 - 88ms/epoch - 4ms/step
# Epoch 72/100
# 23/23 - 0s - loss: 17.9011 - val_loss: 108.9703 - 87ms/epoch - 4ms/step
# Epoch 73/100
# 23/23 - 0s - loss: 17.5612 - val_loss: 115.1157 - 86ms/epoch - 4ms/step
# Epoch 74/100
# 23/23 - 0s - loss: 18.0552 - val_loss: 101.9702 - 86ms/epoch - 4ms/step
# Epoch 75/100
# 23/23 - 0s - loss: 18.0795 - val_loss: 107.8368 - 82ms/epoch - 4ms/step
# Epoch 76/100
# 23/23 - 0s - loss: 17.5054 - val_loss: 101.9537 - 83ms/epoch - 4ms/step
# Epoch 77/100
# 23/23 - 0s - loss: 17.7272 - val_loss: 109.9816 - 89ms/epoch - 4ms/step
# Epoch 78/100
# 23/23 - 0s - loss: 17.7080 - val_loss: 114.8458 - 94ms/epoch - 4ms/step
# Epoch 79/100
# 23/23 - 0s - loss: 17.5408 - val_loss: 112.1724 - 93ms/epoch - 4ms/step
# Epoch 80/100
# 23/23 - 0s - loss: 17.2776 - val_loss: 107.8845 - 84ms/epoch - 4ms/step
# Epoch 81/100
# 23/23 - 0s - loss: 17.1548 - val_loss: 103.5836 - 91ms/epoch - 4ms/step
# Epoch 82/100
# 23/23 - 0s - loss: 17.3691 - val_loss: 111.7234 - 86ms/epoch - 4ms/step
# Epoch 83/100
# 23/23 - 0s - loss: 17.1776 - val_loss: 120.3653 - 89ms/epoch - 4ms/step
# Epoch 84/100
# 23/23 - 0s - loss: 17.9664 - val_loss: 110.4579 - 87ms/epoch - 4ms/step
# Epoch 85/100
# 23/23 - 0s - loss: 17.3946 - val_loss: 99.9838 - 98ms/epoch - 4ms/step
# Epoch 86/100
# 23/23 - 0s - loss: 17.5782 - val_loss: 103.6112 - 89ms/epoch - 4ms/step
# Epoch 87/100
# 23/23 - 0s - loss: 16.9884 - val_loss: 102.8846 - 84ms/epoch - 4ms/step
# Epoch 88/100
# 23/23 - 0s - loss: 17.1520 - val_loss: 99.5347 - 88ms/epoch - 4ms/step
# Epoch 89/100
# 23/23 - 0s - loss: 17.1962 - val_loss: 94.2354 - 90ms/epoch - 4ms/step
# Epoch 90/100
# 23/23 - 0s - loss: 17.0811 - val_loss: 102.9064 - 88ms/epoch - 4ms/step
# Epoch 91/100
# 23/23 - 0s - loss: 16.7949 - val_loss: 106.6722 - 93ms/epoch - 4ms/step
# Epoch 92/100
# 23/23 - 0s - loss: 16.4423 - val_loss: 110.7339 - 84ms/epoch - 4ms/step
# Epoch 93/100
# 23/23 - 0s - loss: 16.4430 - val_loss: 104.5698 - 93ms/epoch - 4ms/step
# Epoch 94/100
# 23/23 - 0s - loss: 16.4358 - val_loss: 108.1612 - 83ms/epoch - 4ms/step
# Epoch 95/100
# 23/23 - 0s - loss: 16.3470 - val_loss: 106.4083 - 95ms/epoch - 4ms/step
# Epoch 96/100
# 23/23 - 0s - loss: 16.5058 - val_loss: 103.2173 - 89ms/epoch - 4ms/step
# Epoch 97/100
# 23/23 - 0s - loss: 16.0439 - val_loss: 95.2283 - 84ms/epoch - 4ms/step
# Epoch 98/100
# 23/23 - 0s - loss: 16.3012 - val_loss: 106.1023 - 89ms/epoch - 4ms/step
# Epoch 99/100
# 23/23 - 0s - loss: 16.2098 - val_loss: 104.6289 - 95ms/epoch - 4ms/step
# Epoch 100/100
# 23/23 - 0s - loss: 16.2900 - val_loss: 99.1961 - 99ms/epoch - 4ms/step

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork945-2022-01-01) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Muhammad Zeeshan](www.linkedin.com/in/muhammadzeeshan007). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2023-11-11  | 2.0  | Muhammad Zeeshan  |  XBOOM AI Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © XBOOM AI Corporation 2023. All rights reserved. <h3/>

# %% [markdown]
# This notebook is part of a course on **XBOOM AI** called *Introduction to Deep Learning & Neural Networks with Keras*. If you accessed this notebook outside the course, you can take this course online by clicking [here](www.linkedin.com/in/muhammadzeeshan007).

# %% [markdown]
# <hr>
#
# Copyright &copy; 2023 [XBOOM AI  Developer Skills Network](www.linkedin.com/in/muhammadzeeshan007). This notebook and its source code are released under the terms of the [MIT License](www.linkedin.com/in/muhammadzeeshan007).
